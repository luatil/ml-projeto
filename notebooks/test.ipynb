# %%
import torch.nn as nn
import torch.optim as optim
from cifar10_model import CIFAR10TrainingModel
from torchvision import transforms


class SNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Flatten(),
            nn.Linear(3072, 50),
            nn.Tanh(),
            nn.Linear(50, 10)
        )

    def forward(self, x):
        return self.model(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [6], in <cell line: 3>()
#       1 import torch.nn as nn
#       2 import torch.optim as optim
# ----> 3 from cifar10_model import CIFAR10TrainingModel
#       4 from torchvision import transforms
#       7 class SNN(nn.Module):
#
# ModuleNotFoundError: No module named 'cifar10_model'

# %%
model = CIFAR10TrainingModel(model=SNN(),
                             learning_rate=1e-3,
                             optimizer=optim.Adam,
                             loss_fn=nn.CrossEntropyLoss())
model.load_and_transform_data(transform_list=transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4915, 0.4823, 0.4468),
                         (0.2470, 0.2435, 0.2616))
]))
# Out:
# Files already downloaded and verified

# %%
model.train(3)
# Out:
# Epoch:   1 Training Acc: 0.382 Training Loss: 0.0277 Validation Acc: 0.364 Validation Loss: 0.0284
# Epoch:   2 Training Acc: 0.407 Training Loss: 0.0266 Validation Acc: 0.388 Validation Loss: 0.0276
# Epoch:   3 Training Acc: 0.416 Training Loss: 0.0263 Validation Acc: 0.393 Validation Loss: 0.0272

# %%
model.plot_acc('asdf')

# %%
model.transform_list

# %%
model.plot_loss('asdf')

# %%
model.save_model('model/test.pth')

# %%
model.load_model('model/test.pth')

# %%
model.calc_val_acc_and_loss()
# Out:
# (0.3931, 0.02724795060157776)

# %%
import requests
from PIL import Image
from matplotlib import pyplot as plt

url = 'https://c8.alamy.com/comp/DYC06A/hornless-reindeer-at-zoo-DYC06A.jpg'
response = requests.get(url, stream=True)
img = Image.open(response.raw)
plt.imshow(img)

# %%
transform = transforms.Compose([transforms.Resize((32,32)),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 transform = transforms.Compose([transforms.Resize((32,32)),
#       2                                 transforms.ToTensor(),
#       3                                 transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
#       4                                 ])
#
# NameError: name 'transforms' is not defined
